# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import re
import gzip
import mav_parse as mp
import numpy as np
from tqdm import tqdm, tqdm_notebook
import pandas as pd

# %%
path = "mav201901.t18z.gz"

# %%
#find new lines in the file
empty= re.compile(b'\s+\n')

# %%
x=0
s=0
station = []
dfs = []
with gzip.open(path, 'r') as f:
    for i, line in tqdm_notebook(enumerate(f), desc='lines'):
        #if i >495:
            #break
        if not empty.match(line):
            station.append(line.decode())
        else:  
            try:
                dfs.append(mp.parse_station(station))
                s+=1
            except ValueError:
                print(station[0])
                x+=1
            except KeyError as e:
                print(e)
                print(station[0])
                x+=1
            station = []
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='lines', max=1, style=ProgressStyle(descript…
# 1
#
#  PHJH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K1P1   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K1V4   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAFN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KALB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAPG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAQW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KART   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KASH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAUG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAVP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBAF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBDL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBDR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBED   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBGM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBGR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBHB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBML   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBOS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBTV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBUF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBVI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBVY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCAR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCDA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCEF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCGF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCON   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCQX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDAW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDDH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDFI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDKK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDSV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDXR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEEN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEFK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KELM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEWB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFDY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFIT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFMH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFOK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFSO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFVE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFWN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFZY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGFL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGHG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGNR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGON   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGTB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHFD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHIE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHUL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHVN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHWV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHYA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHZY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIAG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIJD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KISP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KITH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIWI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIZG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJHW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLCI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLEB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLEW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLPR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLWM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMGJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMHT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMLT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMMK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMPV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMQE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMSS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMSV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMVL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMVY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMWN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOQU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KORE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KORH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOWD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOXC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPBG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPEO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPOU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPQI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPSF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPSM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPVC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPVD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPWM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPYM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRKD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRME   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KROC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRUT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSCH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSFM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSFZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSLK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSNC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSWF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSYR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTAN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTDZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTOL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUUU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVSF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KWST   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KWVL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBCT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KISM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLZU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRYY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTIX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  TJBQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  TJPS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  TKPK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K04W   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K06D   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K08D   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K14Y   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K21D   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K2C8   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K2D5   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K2WX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K5H4   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K7L2   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K8D3   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K96D   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K9D7   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K9MN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K9V9   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAAA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KABR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KACB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KACQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KADC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KADG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KADU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAEL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAFK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAHQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAIA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAID   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAIG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAIO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAIT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KALO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAMN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAMW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KANE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KANJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KANW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAPN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAQP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KARB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KARR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KARV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KASW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KASX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KATW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KATY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAUH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAUM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAUW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAWG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAXA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAXN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAZO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBAX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBBB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBBW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBCK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBDE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBDH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBEH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBFF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBFW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBIE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBIS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBIV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBJI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBKX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBMI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBNW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBRD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBRL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBTA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBTL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBUU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBVN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBWP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KC09   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KC29   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KC75   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCAD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCAV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCBF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCBG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCCY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCDD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCDR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCFE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCFS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCID   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCIN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCIU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCKC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCKN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCKP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCLI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCMX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCMY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCNB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCNC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCOQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCQM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCSQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCUT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCVX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCWA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCWI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KD07   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KD39   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KD50   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KD55   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDBQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDEH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDET   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDIK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDKB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDLH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDLL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDNS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDNV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDPA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDRM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDSM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDTL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDTW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDUH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDVL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDVN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDVP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDXX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDYT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEAR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEAU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEBS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEFT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEGV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEHA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KELO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KENW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEOK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KERY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KESC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEST   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KETB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KETH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEVM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEZS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFAR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFBL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFCM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFEP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFET   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFFL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFFM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFFX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFGN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFKA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFKS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFLD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFNB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFNT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFOD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFOZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFPK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFRM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFSD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFSE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFSW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFWA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFXY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGAF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGBG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGDB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGFK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGGI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGHW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGLR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGNA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGOV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGPZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGRB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGRI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGRR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGSH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGUS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGWB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGYL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGYY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHAI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHCD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHCO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHDE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHEI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHIB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHJH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHNR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHON   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHSI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHTL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHYR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHYX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHZE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHZX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KI75   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIBM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KICL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KICR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIEN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIFA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIGQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIIB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIKK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIKV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIKW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIML   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIMT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KINL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIOW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIRK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIRS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KISN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KISQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KISW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIWD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJKJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJMR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJMS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJOT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJVL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJXN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJYG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJYM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJYR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLAF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLAN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLBF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLCG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLDM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLJF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLNK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLNL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLNR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLOT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLRJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLSE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLUM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLVN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLWA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLWD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLXL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLXN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLYV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMBG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMBL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMBS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMCD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMCI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMCK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMCW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMDS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMDW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMDZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMFI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMGG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMGN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMHE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMIB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMIC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMIW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMJQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMKE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMKG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMKT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMLE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMLI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMML   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMNM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMOP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMOT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMOX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMPZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMQB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMRJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMSN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMSP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMTC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMTW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMUT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMVE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMWC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMWM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMXO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMZH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KN60   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KODX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOEB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOEO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOFF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOFK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOGA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOLU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOLZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOMA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KONA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KONL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KONZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOOA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KORB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KORC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KORD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOSC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOSH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOTG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOTM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOVL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOVS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOWA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOXI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOXV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOZW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KP53   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KP58   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KP59   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPBH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPCZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPDC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPEA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPEX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPHN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPHP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPIA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPIR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPKD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPLN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPMV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPNM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPNT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPPO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPPQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPQN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPRO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPTK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPVB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPWC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPWK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPZQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRAC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRAP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRCA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRCR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRCX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRDK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRDR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRFD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRGK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRHI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRMY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRNH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRNP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KROS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KROX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRPD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRPJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRQB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRRL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRRT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRST   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRUG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRWF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRYV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRZL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRZN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KS25   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KS32   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSAW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSAZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSBM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSBN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSDA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSFY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSGS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSHL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSJX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSLB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSLH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSNY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSPF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSPW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSQI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSTC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSTE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSTJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSTP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSUE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSUW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSUX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KSYN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTEW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTIF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTIP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTKC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTKV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTNU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTOB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTQE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTTF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTVC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTVF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTVK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KTWM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUBE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUES   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUGN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUIN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KULM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KUNU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVLL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVOK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVPZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVTI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVTN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVVV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVWU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KVYS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KXVG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KY19   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KY50   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KY51   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KY63   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KY70   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KYIP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KYKN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KASG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHRX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K04V   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K0E0   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K1U7   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K20V   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K2V5   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K33V   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHCR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K3MW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K4BM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K4MR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  K7BM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KABQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAEG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAFF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAKO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KALS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KANK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAPA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KASE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KATS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KAXX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBCE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBHK   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBIL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBKF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBPI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBTM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBYG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBYI   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KBZN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCAG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCAO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCCU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCDC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCEZ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCHD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCMR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCNY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCOD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCOS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCPR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCPW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCQC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCVN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCVS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCXP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KCYS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDGW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDIJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDLN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDRA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KDRO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEEO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEGE   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEKO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KELY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KENV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KEVW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFCS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFEW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFLG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFLY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFMN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KFTG   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGCC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGCN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGDV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGEU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGEY   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGJT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGNT   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGUC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGUP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KGYR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHDN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHEQ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KHIF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KIDA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KINW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KITR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJAC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KJER   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLAA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLAM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLAR   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLGU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLHX   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLIC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLND   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLOL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLVM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLVS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KLXV   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMLF   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMLP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMNH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMSO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMTJ   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMYL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KMYP   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KNFL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KOGD   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KONM   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KP60   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KP68   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPAN   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPGA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPIH   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPNA   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPSO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPUB   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPUC   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KPVU   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRIL   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRIW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRKS   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KRNO   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
#  KROW   GFS MOS GUIDANCE    1/01/2019  1800 UTC
#
# ...
#
#  PAIG   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAII   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAIL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAIN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAJC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAJZ   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKI   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PALG   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PALJ   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMB   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMY   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PANI   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PANW   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAOO   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAOU   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAPB   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAPH   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAPN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASV   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATG   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAVA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAVD   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAWN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAWS   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAZK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PABA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PABI   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PABL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PABR   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PABT   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PACM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PADE   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PADM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAEG   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAEI   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAEM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAFA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAFB   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAFM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAFS   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAGA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAGH   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAGL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAGM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAHC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAHL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAIK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAIM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAIW   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKP   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKU   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAKV   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PALP   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PALU   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMH   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAMO   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PANN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PANV   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAOM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAOR   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAOT   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAPO   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAQT   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PARC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PARS   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PARY   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASH   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASK   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PASM   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATA   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATC   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATE   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PATQ   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAUN   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAVL   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PAWI   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PFNO   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PFYU   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
#  PPIZ   GFS MOS GUIDANCE    1/16/2019  1800 UTC
#
# 1
#
#  PHJH   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  K1V4   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  K4I3   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAFJ   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAGC   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAKR   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAOH   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAPG   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KART   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KAUG   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBFD   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBGR   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBHB   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBJJ   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBKL   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBML   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBTP   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBTV   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBUF   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KBVI   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCAK   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCAR   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCDA   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCGF   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCLE   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KCRW   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDAY   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDFI   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDKK   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDLZ   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDSV   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KDUJ   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KEFK   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KELM   GFS MOS GUIDANCE    1/17/2019  1800 UTC
#
#  KELZ   GFS MOS GUIDANCE    1/17/2019  1800 UTC
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in try_datetime(v)
#     894                                         require_iso8601=True,
# --> 895                                         errors='raise')[0]
#     896         except ValueError:
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ValueError: Tz-aware datetime.datetime cannot be converted to datetime64 unless utc=True
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-773c8c0b23fb> in <module>
#      11         else:
#      12             try:
# ---> 13                 dfs.append(mp.parse_station(station))
#      14                 s+=1
#      15             except ValueError:
#
# ~/mos/mav_parse.py in parse_station(station)
#      86     header = get_header(station[0])
#      87     header['ftime']= get_fntime(station[1], station[2], header)
# ---> 88     df = get_rows(header, station)
#      89     return df
#
# ~/mos/mav_parse.py in get_rows(header, station)
#      64
#      65 def get_rows(header, station):
# ---> 66     df = pd.DataFrame(header)
#      67     for row in station[3:]:
#      68         #cranky parsing issues
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     390                                  dtype=dtype, copy=copy)
#     391         elif isinstance(data, dict):
# --> 392             mgr = init_dict(data, index, columns, dtype=dtype)
#     393         elif isinstance(data, ma.MaskedArray):
#     394             import numpy.ma.mrecords as mrecords
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     210         arrays = [data[k] for k in keys]
#     211
# --> 212     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     213
#     214
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#      54
#      55     # don't force copy because getting jammed in an ndarray anyway
# ---> 56     arrays = _homogenize(arrays, index, dtype)
#      57
#      58     # from BlockManager perspective
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/construction.py in _homogenize(data, index, dtype)
#     275                 val = lib.fast_multiget(val, oindex.values, default=np.nan)
#     276             val = sanitize_array(val, index, dtype=dtype, copy=False,
# --> 277                                  raise_cast_failure=False)
#     278
#     279         homogenized.append(val)
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     623         subarr = _try_cast(arr, False, dtype, copy, raise_cast_failure)
#     624     else:
# --> 625         subarr = _try_cast(data, False, dtype, copy, raise_cast_failure)
#     626
#     627     # scalar like, GH
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/construction.py in _try_cast(arr, take_fast_path, dtype, copy, raise_cast_failure)
#     695             subarr = maybe_cast_to_integer_array(arr, dtype)
#     696
# --> 697         subarr = maybe_cast_to_datetime(arr, dtype)
#     698         # Take care in creating object arrays (but iterators are not
#     699         # supported):
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_cast_to_datetime(value, dtype, errors)
#    1065         elif not (is_array and not (issubclass(value.dtype.type, np.integer) or
#    1066                                     value.dtype == np.object_)):
# -> 1067             value = maybe_infer_to_datetimelike(value)
#    1068
#    1069     return value
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in maybe_infer_to_datetimelike(value, convert_dates)
#     929         value = try_datetime(v)
#     930     elif inferred_type == 'datetime':
# --> 931         value = try_datetime(v)
#     932     elif inferred_type == 'timedelta':
#     933         value = try_timedelta(v)
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in try_datetime(v)
#     904
#     905                 values, tz = conversion.datetime_to_datetime64(v)
# --> 906                 return DatetimeIndex(values).tz_localize(
#     907                     'UTC').tz_convert(tz=tz)
#     908             except (ValueError, TypeError):
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/datetimes.py in __new__(cls, data, freq, start, end, periods, tz, normalize, closed, ambiguous, dayfirst, yearfirst, dtype, copy, name, verify_integrity)
#     301             data, dtype=dtype, copy=copy, tz=tz, freq=freq,
#     302             dayfirst=dayfirst, yearfirst=yearfirst, ambiguous=ambiguous,
# --> 303             int_as_wall_time=True)
#     304
#     305         subarr = cls._simple_new(dtarr, name=name,
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in _from_sequence(cls, data, dtype, copy, tz, freq, dayfirst, yearfirst, ambiguous, int_as_wall_time)
#     374             data, dtype=dtype, copy=copy, tz=tz,
#     375             dayfirst=dayfirst, yearfirst=yearfirst,
# --> 376             ambiguous=ambiguous, int_as_wall_time=int_as_wall_time)
#     377
#     378         freq, freq_infer = dtl.validate_inferred_freq(freq, inferred_freq,
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in sequence_to_dt64ns(data, dtype, copy, tz, dayfirst, yearfirst, ambiguous, int_as_wall_time)
#    1743
#    1744     # By this point we are assured to have either a numpy array or Index
# -> 1745     data, copy = maybe_convert_dtype(data, copy)
#    1746
#    1747     if is_object_dtype(data) or is_string_dtype(data):
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/arrays/datetimes.py in maybe_convert_dtype(data, copy)
#    1929                         "Use `data.to_timestamp()` instead")
#    1930
# -> 1931     elif is_categorical_dtype(data):
#    1932         # GH#18664 preserve tz in going DTI->Categorical->DTI
#    1933         # TODO: cases where we need to do another pass through this func,
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/common.py in is_categorical_dtype(arr_or_dtype)
#     600     if arr_or_dtype is None:
#     601         return False
# --> 602     return CategoricalDtype.is_dtype(arr_or_dtype)
#     603
#     604
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/base.py in is_dtype(cls, dtype)
#      99
#     100         if isinstance(dtype, (ABCSeries, ABCIndexClass,
# --> 101                               ABCDataFrame, np.dtype)):
#     102             # https://github.com/pandas-dev/pandas/issues/22960
#     103             # avoid passing data to `construct_from_string`. This could
#
# KeyboardInterrupt:

# %%
s,x
# Out:
# [autoreload of test_station failed: Traceback (most recent call last):
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home1/oscarlucero/mos/test_station.py", line 10
#     row1 =
#           ^
# SyntaxError: invalid syntax
# ]
# (20979, 11381)

# %%
mp.get_header(station[0])
# Out:
# {'station': 'KBFW',
#  'model': 'GFS MOS GUIDANCE',
#  'runtime': datetime.datetime(2019, 1, 1, 18, 0, tzinfo=tzutc())}

# %%
station[1]
# Out:
# [autoreload of test_station failed: Traceback (most recent call last):
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/home1/oscarlucero/miniconda3/envs/mos/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home1/oscarlucero/mos/test_station.py", line 10
#     row1 =
#           ^
# SyntaxError: invalid syntax
# ]
# ' DT /JAN  18                  /JAN  19                /JAN  20       \n'

# %%
h = mp.get_header(station[0])
h
# Out:
# {'station': 'KBFW',
#  'model': 'GFS MOS GUIDANCE',
#  'runtime': datetime.datetime(2019, 1, 1, 18, 0, tzinfo=tzutc())}

# %%
station[1:3]
# Out:
# [' DT /JAN   2                  /JAN   3                /JAN   4       \n',
#  ' HR   00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 12 18 \n']

# %%
ftimes = mp.get_fntime(station[1], station[2], h)

# %%
mp.parse_station(station)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-e832d77de72f> in <module>
# ----> 1 mp.parse_station(station)
#
# ~/mos/mav_parse.py in parse_station(station)
#      86     header = get_header(station[0])
#      87     header['ftime']= get_fntime(station[1], station[2], header)
# ---> 88     df = get_rows(header, station)
#      89     return df
#
# ~/mos/mav_parse.py in get_rows(header, station)
#      78             df[var] = np.array(vals, dtype='object')
#      79         elif var in integer: # cast to int
# ---> 80             df[var] = np.array(vals, dtype='float64')
#      81         else:
#      82             raise KeyError(f"{var} parsing not supported")
#
# ValueError: could not convert string to float: '-8-12-11-10'

# %%
# %debug
mp.get_rows(h, station)

# %%
import test_station
test_station.test_get_header()

# %%
dfs[50]
# Out:
#    station             model                   runtime               ftime  \
# 0     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 00:00:00
# 1     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 03:00:00
# 2     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 06:00:00
# 3     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 09:00:00
# 4     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 12:00:00
# 5     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 15:00:00
# 6     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 18:00:00
# 7     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 21:00:00
# 8     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 00:00:00
# 9     KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 03:00:00
# 10    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 06:00:00
# 11    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 09:00:00
# 12    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 12:00:00
# 13    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 15:00:00
# 14    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 18:00:00
# 15    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 21:00:00
# 16    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 00:00:00
# 17    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 03:00:00
# 18    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 06:00:00
# 19    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 12:00:00
# 20    KCRW  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 18:00:00
#
#      N/X   TMP   DPT CLD   WDR  WSP  ...   Q12   T06   T12  POZ   POS TYP  \
# 0    NaN  44.0  40.0  OV  33.0  3.0  ...  None  None  None  0.0   0.0   R
# 1    NaN  44.0  41.0  OV  32.0  1.0  ...  None  None  None  0.0   0.0   R
# 2    NaN  42.0  39.0  OV   0.0  0.0  ...  None  0/ 4  None  0.0   8.0   R
# 3    NaN  39.0  37.0  OV   4.0  1.0  ...  None  None  None  0.0   1.0   R
# 4   37.0  38.0  35.0  OV   7.0  1.0  ...     0  0/ 5  None  0.0   0.0   R
# 5    NaN  42.0  37.0  OV  10.0  1.0  ...  None  None  None  2.0   0.0   R
# 6    NaN  49.0  39.0  OV  19.0  3.0  ...  None  0/ 0  0/ 6  1.0   0.0   R
# 7    NaN  52.0  39.0  OV  21.0  4.0  ...  None  None  None  0.0   0.0   R
# 8   53.0  49.0  40.0  OV  19.0  3.0  ...     0  1/ 0  None  1.0   0.0   R
# 9    NaN  49.0  40.0  OV  22.0  4.0  ...  None  None  None  1.0   0.0   R
# 10   NaN  47.0  38.0  OV  25.0  7.0  ...  None  1/ 8  1/ 8  1.0   0.0   R
# 11   NaN  43.0  36.0  OV  27.0  9.0  ...  None  None  None  0.0  12.0   R
# 12  39.0  40.0  34.0  OV  27.0  6.0  ...     1  0/ 5  None  0.0  11.0   R
# 13   NaN  39.0  31.0  OV  26.0  5.0  ...  None  None  None  1.0  30.0   R
# 14   NaN  43.0  29.0  BK  27.0  5.0  ...  None  0/ 6  1/11  0.0  32.0   R
# 15   NaN  46.0  27.0  SC  25.0  5.0  ...  None  None  None  0.0  19.0   R
# 16  47.0  41.0  28.0  CL  24.0  1.0  ...     0  0/ 0  None  0.0  33.0   R
# 17   NaN  37.0  30.0  FW   0.0  0.0  ...  None  None  None  0.0  11.0   R
# 18   NaN  36.0  31.0  CL   0.0  0.0  ...  None  0/ 2  0/ 4  0.0  14.0   R
# 19  31.0  32.0  29.0  FW   0.0  0.0  ...     0  None  None  0.0  14.0   R
# 20   NaN  48.0  33.0  BK   8.0  3.0  ...  None  0/ 0  0/ 1  0.0   0.0   R
#
#     SNW  CIG  VIS  OBV
# 0   NaN  4.0  7.0    N
# 1   NaN  4.0  7.0    N
# 2   NaN  5.0  7.0    N
# 3   NaN  5.0  5.0   BR
# 4   NaN  5.0  7.0    N
# 5   NaN  8.0  7.0    N
# 6   NaN  7.0  7.0    N
# 7   NaN  7.0  7.0    N
# 8   NaN  7.0  7.0    N
# 9   NaN  5.0  7.0    N
# 10  NaN  4.0  5.0    N
# 11  NaN  5.0  7.0    N
# 12  0.0  5.0  7.0    N
# 13  NaN  5.0  7.0    N
# 14  NaN  8.0  7.0    N
# 15  NaN  8.0  7.0    N
# 16  NaN  8.0  7.0    N
# 17  NaN  8.0  7.0    N
# 18  NaN  8.0  7.0    N
# 19  0.0  8.0  7.0    N
# 20  NaN  8.0  7.0    N
#
# [21 rows x 23 columns]
