# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import re
import gzip
import mav_parse as mp
import numpy as np
from tqdm import tqdm, tqdm_notebook
import pandas as pd

# %%
path = "mav201901.t18z.gz"

# %%
#find new lines in the file
empty= re.compile(b'\s+\n')
newline = re.compile(b'1\n')

# %%
x=0
s=0
station = []
stations = []
with gzip.open(path, 'r') as f:
    for i, line in tqdm_notebook(enumerate(f), desc='lines'):
        if empty.match(line):
            stations.append(station)
            station=[]
        elif newline.match(line):
            pass
        else:
            station.append(line.decode())
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', description='lines', max=1, style=ProgressStyle(descript…
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WDR'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1052         try:
# -> 1053             loc = self.items.get_loc(item)
#    1054         except KeyError:
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'WDR'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-44f13bccbc67> in <module>
#       7         if empty.match(line):
#       8             try:
# ----> 9                 dfs.append(mp.parse_station(station))
#      10                 s+=1
#      11             except ValueError as e:
#
# ~/mos/mav_parse.py in parse_station(station)
#      78     header = get_header(station[0])
#      79     header['ftime']= get_fntime(station[1], station[2], header)
# ---> 80     df = get_rows(header, station)
#      81     return df
#
# ~/mos/mav_parse.py in get_rows(header, station)
#      68             df[var] = np.array(vals, dtype='object')
#      69         elif var in integer: # cast to int
# ---> 70             df[var] = np.array(vals, dtype='float64')
#      71         else:
#      72             raise KeyError(f"{var} parsing not supported")
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3368         else:
#    3369             # set column
# -> 3370             self._set_item(key, value)
#    3371
#    3372     def _setitem_slice(self, key, value):
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3444         self._ensure_valid_index(value)
#    3445         value = self._sanitize_column(key, value)
# -> 3446         NDFrame._set_item(self, key, value)
#    3447
#    3448         # check if we are modifying a copy
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/generic.py in _set_item(self, key, value)
#    3170
#    3171     def _set_item(self, key, value):
# -> 3172         self._data.set(key, value)
#    3173         self._clear_item_cache()
#    3174
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/managers.py in set(self, item, value)
#    1054         except KeyError:
#    1055             # This item wasn't present, just insert at end
# -> 1056             self.insert(len(self.items), item, value)
#    1057             return
#    1058
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1153
#    1154         # insert to the axis; this could possibly raise a TypeError
# -> 1155         new_axis = self.items.insert(loc, item)
#    1156
#    1157         block = make_block(values=value, ndim=self.ndim,
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/base.py in insert(self, loc, item)
#    4933         """
#    4934         _self = np.asarray(self)
# -> 4935         item = self._coerce_scalar_to_index(item)._ndarray_values
#    4936         idx = np.concatenate((_self[:loc], item, _self[loc:]))
#    4937         return self._shallow_copy_with_infer(idx)
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/base.py in _coerce_scalar_to_index(self, item)
#    3843             dtype = None
#    3844
# -> 3845         return Index([item], dtype=dtype, **self._get_attributes_dict())
#    3846
#    3847     def _to_safe_for_reshape(self):
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     480                         data, names=name or kwargs.get('names'))
#     481             # other iterable of some kind
# --> 482             subarr = com.asarray_tuplesafe(data, dtype=object)
#     483             return Index(subarr, dtype=dtype, copy=copy, name=name, **kwargs)
#     484
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/common.py in asarray_tuplesafe(values, dtype)
#     228
#     229     if isinstance(values, list) and dtype in [np.object_, object]:
# --> 230         return construct_1d_object_array_from_listlike(values)
#     231
#     232     result = np.asarray(values, dtype=dtype)
#
# ~/miniconda3/envs/mos/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in construct_1d_object_array_from_listlike(values)
#    1211     # numpy will try to interpret nested lists as further dimensions, hence
#    1212     # making a 1D array that contains list-likes is a bit tricky:
# -> 1213     result = np.empty(len(values), dtype='object')
#    1214     result[:] = values
#    1215     return result
#
# KeyboardInterrupt:

# %%
mp.parse_station(station)

# %%
s,x
# Out:
# (20999, 0)

# %%
mp.get_header(station[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-e5890cd4402c> in <module>
# ----> 1 mp.get_header(station[0])
#
# IndexError: list index out of range

# %%
station[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-8391148dc223> in <module>
# ----> 1 station[1]
#
# IndexError: list index out of range

# %%
h = mp.get_header(station[0])
h
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-42-cdc80183a3f5> in <module>
# ----> 1 h = mp.get_header(station[0])
#       2 h
#
# IndexError: list index out of range

# %%
station[1:3]
# Out:
# []

# %%
ftimes = mp.get_fntime(station[1], station[2], h)

# %%
mp.parse_station(station)

# %%
# %debug
mp.get_rows(h, station)

# %%
import test_station
test_station.test_get_header()

# %%
dfs[50]
# Out:
#    station             model                   runtime               ftime  \
# 0     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 00:00:00
# 1     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 03:00:00
# 2     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 06:00:00
# 3     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 09:00:00
# 4     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 12:00:00
# 5     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 15:00:00
# 6     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 18:00:00
# 7     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-02 21:00:00
# 8     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 00:00:00
# 9     KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 03:00:00
# 10    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 06:00:00
# 11    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 09:00:00
# 12    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 12:00:00
# 13    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 15:00:00
# 14    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 18:00:00
# 15    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-03 21:00:00
# 16    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 00:00:00
# 17    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 03:00:00
# 18    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 06:00:00
# 19    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 12:00:00
# 20    KBID  GFS MOS GUIDANCE 2019-01-01 18:00:00+00:00 2019-01-04 18:00:00
#
#      N/X   TMP   DPT CLD   WDR   WSP  ...   Q12     T06     T12  POZ   POS  \
# 0    NaN  41.0  23.0  CL  32.0  13.0  ...  None    None    None  0.0  33.0
# 1    NaN  38.0  22.0  CL  32.0  11.0  ...  None       0    None  0.0  65.0
# 2    NaN  34.0  17.0  CL  33.0   9.0  ...  None    None    None  0.0  81.0
# 3    NaN  31.0  13.0  CL  34.0   8.0  ...  None  / 2  0    None  0.0  83.0
# 4   29.0  29.0  11.0  CL  36.0   7.0  ...     0    None    None  0.0  77.0
# 5    NaN  32.0  10.0  CL   1.0   8.0  ...  None  / 4  0       0  0.0  83.0
# 6    NaN  34.0  11.0  CL   3.0   6.0  ...  None    None    None  0.0  99.0
# 7    NaN  35.0  13.0  CL  14.0   5.0  ...  None  / 2  0     /10  1.0  99.0
# 8   36.0  33.0  15.0  SC  15.0   5.0  ...     0    None    None  1.0  99.0
# 9    NaN  33.0  18.0  SC  15.0   7.0  ...  None  / 3  0       0  0.0  94.0
# 10   NaN  36.0  25.0  OV  17.0   8.0  ...  None    None    None  0.0  69.0
# 11   NaN  39.0  30.0  OV  17.0   8.0  ...  None  / 0  0     / 3  0.0  47.0
# 12  33.0  41.0  34.0  OV  16.0   9.0  ...     1    None    None  4.0  45.0
# 13   NaN  43.0  38.0  OV  18.0   8.0  ...  None  / 6  0       0  0.0  10.0
# 14   NaN  44.0  35.0  OV  27.0  11.0  ...  None    None    None  0.0  12.0
# 15   NaN  44.0  33.0  FW  31.0   9.0  ...  None  / 1  0     / 6  0.0  16.0
# 16  47.0  41.0  29.0  CL  32.0  10.0  ...     2    None    None  0.0  46.0
# 17   NaN  38.0  26.0  CL  31.0  10.0  ...  None  / 0  0       0  0.0  59.0
# 18   NaN  37.0  25.0  CL  31.0   9.0  ...  None    None    None  1.0  63.0
# 19  34.0  36.0  25.0  CL  27.0   8.0  ...     0  / 1  0  / 1  0  4.0  46.0
# 20   NaN  44.0  29.0  CL  24.0  15.0  ...  None    None    None  1.0   0.0
#
#    TYP  SNW  CIG  VIS  OBV
# 0    R  NaN  8.0  7.0    N
# 1    S  NaN  8.0  7.0    N
# 2    S  NaN  8.0  7.0    N
# 3    S  NaN  8.0  7.0    N
# 4    S  NaN  8.0  7.0    N
# 5    S  NaN  8.0  7.0    N
# 6    S  NaN  8.0  7.0    N
# 7    S  NaN  8.0  7.0    N
# 8    S  NaN  8.0  7.0    N
# 9    S  NaN  8.0  7.0    N
# 10   S  NaN  6.0  7.0    N
# 11   S  NaN  6.0  7.0    N
# 12   R  1.0  3.0  4.0   BR
# 13   R  NaN  2.0  2.0   BR
# 14   R  NaN  3.0  6.0    N
# 15   R  NaN  8.0  7.0    N
# 16   R  NaN  8.0  7.0    N
# 17   S  NaN  8.0  7.0    N
# 18   S  NaN  8.0  7.0    N
# 19   S  0.0  8.0  7.0    N
# 20   R  NaN  8.0  7.0    N
#
# [21 rows x 23 columns]
